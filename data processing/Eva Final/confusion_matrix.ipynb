# %%
import pandas as pd

# %%
df = pd.read_csv('predicted_plan_div3.csv')

df.rename(columns= {'Predicted Plan' : 'predicted_plan'},inplace=True)

# %%
df.head(10)
# Out:
#    Unnamed: 0  users.user_id users.plan_purchase_date happychat_session_date  \
# 0       14031       33521066               2018-09-28             2019-04-17
# 1       13265       59437390               2018-08-21             2018-09-12
# 2       13180       55965321               2018-08-28             2018-09-23
# 3       24409       71871584               2019-03-31             2019-04-23
# 4       16687         963790               2018-11-20             2018-11-20
# 5        3001       23258094               2018-02-15             2018-02-15
# 6       10759       24673921               2018-07-02             2018-09-24
# 7        8061       37428550               2018-05-24             2018-05-24
# 8       20722       23016360               2019-01-26             2019-01-29
# 9       26319      122281721               2019-04-30             2019-05-06
#
#    happychat_session_id      plan_purchased plan_purchased_nice  \
# 0              12147694  wp-bundle-business            Business
# 1               6389957  wp-bundle-business            Business
# 2               6654782  wp-personal-bundle            Personal
# 3              12282156  wp-bundle-business            Business
# 4               8201594  wp-personal-bundle            Personal
# 5               1818864  wp-bundle-business            Business
# 6               6683183  wp-bundle-business            Business
# 7               3846029     wp-value-bundle             Premium
# 8               9926182  wp-bundle-business            Business
# 9              12582707  wp-bundle-business            Business
#
#                tag_1          tag_2         tag_3 tag_4 tag_5  \
# 0           bookings              0             0     0     0
# 1      domain_cancel  atomic_revert  refund_other     0     0
# 2              pages    editor_link             0     0     0
# 3  content_portfolio              0             0     0     0
# 4                  0              0             0     0     0
# 5                  0              0             0     0     0
# 6                  0              0             0     0     0
# 7                  0              0             0     0     0
# 8       plan_premium              0             0     0     0
# 9                  0              0             0     0     0
#
#                                            msg_whole predicted_plan
# 0  Hi there!,Got it. Thanks for confirming. ,Your...       Business
# 1  Please note that once the site is reverted to ...       Business
# 2  help re-structuring categories,How are you goi...       Business
# 3  https://kerryoconnorux.com/portfolio/partybudd...       Business
# 4  seems to me, too. can you please give the info...       Business
# 5  I've added it for you now, ,yes*,It looks like...        Premium
# 6  You can take a look at the support document an...        Premium
# 7  Okay! Once you do, let me know, and I'll move ...        Premium
# 8  All finished, you can review your receipt here...       Business
# 9   ,Thanks,No, the media files cannot be organiz...       Business

# %%
busbus = 0
busper = 0
buspre = 0
perbus = 0
perper = 0
perpre = 0
prebus = 0
preper = 0
prepre = 0


for index, row in df.iterrows():
    
    plan = row.plan_purchased_nice
    predicted = row.predicted_plan
    if plan == "Business":
        if predicted == plan:
            busbus += 1
        elif predicted == "Personal":
            busper += 1
        else:
            buspre += 1
    elif plan == "Personal":
        if predicted == plan:
            perper += 1
        elif predicted == "Premium":
            perpre += 1
        else:
            perbus += 1
    else:
        if predicted == plan:
            prepre += 1
        elif predicted == "Business":
            prebus += 1
        else:
            preper += 1
            
print('busbus:', busbus, 'busper: ', busper, "buspre", buspre, "perbus", perbus, "perper", perper, "perpre", perpre, "prebus", prebus, "preper", preper, "prepre", prepre)
# Out:
# busbus: 7344 busper:  342 buspre 2304 perbus 3487 perper 965 perpre 2656 prebus 5687 preper 659 prepre 3212

# %%
p = busbus + perper + prepre
n = busper + buspre + perbus + perpre + prebus +preper

accuracy_div_three = (p)/(p+n)

accuracy_div_three
# Out:
# 0.4322103841536615

# %%
df = pd.read_csv('predicted_plan_div4.csv')

df.rename(columns= {'Predicted Plan' : 'predicted_plan'},inplace=True)

busbus = 0
busper = 0
buspre = 0
perbus = 0
perper = 0
perpre = 0
prebus = 0
preper = 0
prepre = 0


for index, row in df.iterrows():
    
    plan = row.plan_purchased_nice
    predicted = row.predicted_plan
    if plan == "Business":
        if predicted == plan:
            busbus += 1
        elif predicted == "Personal":
            busper += 1
        else:
            buspre += 1
    elif plan == "Personal":
        if predicted == plan:
            perper += 1
        elif predicted == "Premium":
            perpre += 1
        else:
            perbus += 1
    else:
        if predicted == plan:
            prepre += 1
        elif predicted == "Business":
            prebus += 1
        else:
            preper += 1
            
print('busbus:', busbus, 'busper: ', busper, "buspre", buspre, "perbus", perbus, "perper", perper, "perpre", perpre, "prebus", prebus, "preper", preper, "prepre", prepre)
            
            
p = busbus + perper + prepre
n = busper + buspre + perbus + perpre + prebus +preper

accuracy_div_four = (p)/(p+n)

accuracy_div_four
# Out:
# busbus: 5883 busper:  179 buspre 1454 perbus 3058 perper 452 perpre 1851 prebus 4815 preper 327 prepre 1965
# 0.41533226581265015

# %%
df = pd.read_csv('predicted_plan_div5.csv')

df.rename(columns= {'Predicted Plan' : 'predicted_plan'},inplace=True)

busbus = 0
busper = 0
buspre = 0
perbus = 0
perper = 0
perpre = 0
prebus = 0
preper = 0
prepre = 0


for index, row in df.iterrows():
    
    plan = row.plan_purchased_nice
    predicted = row.predicted_plan
    if plan == "Business":
        if predicted == plan:
            busbus += 1
        elif predicted == "Personal":
            busper += 1
        else:
            buspre += 1
    elif plan == "Personal":
        if predicted == plan:
            perper += 1
        elif predicted == "Premium":
            perpre += 1
        else:
            perbus += 1
    else:
        if predicted == plan:
            prepre += 1
        elif predicted == "Business":
            prebus += 1
        else:
            preper += 1
            
print('busbus:', busbus, 'busper: ', busper, "buspre", buspre, "perbus", perbus, "perper", perper, "perpre", perpre, "prebus", prebus, "preper", preper, "prepre", prepre)
            
            
p = busbus + perper + prepre
n = busper + buspre + perbus + perpre + prebus +preper

accuracy_div_five = (p)/(p+n)

accuracy_div_five
# Out:
# busbus: 5866 busper:  24 buspre 112 perbus 3915 perper 86 perpre 246 prebus 5467 preper 33 prepre 235
# 0.38707457457457456

# %%
df = pd.read_csv('predicted_plan_div6.csv')

df.rename(columns= {'Predicted Plan' : 'predicted_plan'},inplace=True)

busbus = 0
busper = 0
buspre = 0
perbus = 0
perper = 0
perpre = 0
prebus = 0
preper = 0
prepre = 0


for index, row in df.iterrows():
    
    plan = row.plan_purchased_nice
    predicted = row.predicted_plan
    if plan == "Business":
        if predicted == plan:
            busbus += 1
        elif predicted == "Personal":
            busper += 1
        else:
            buspre += 1
    elif plan == "Personal":
        if predicted == plan:
            perper += 1
        elif predicted == "Premium":
            perpre += 1
        else:
            perbus += 1
    else:
        if predicted == plan:
            prepre += 1
        elif predicted == "Business":
            prebus += 1
        else:
            preper += 1
            
print('busbus:', busbus, 'busper: ', busper, "buspre", buspre, "perbus", perbus, "perper", perper, "perpre", perpre, "prebus", prebus, "preper", preper, "prepre", prepre)
            
            
p = busbus + perper + prepre
n = busper + buspre + perbus + perpre + prebus +preper

accuracy_div_six = (p)/(p+n)

accuracy_div_six
# Out:
# busbus: 4901 busper:  0 buspre 0 perbus 3581 perper 1 perpre 0 prebus 4827 preper 1 prepre 1
# 0.36831430288461536

# %%
print('div3:', accuracy_div_three, 'div4:', accuracy_div_four, 'div5:', accuracy_div_five, 'div6:', accuracy_div_six)
# Out:
# div3: 0.4322103841536615 div4: 0.41533226581265015 div5: 0.38707457457457456 div6: 0.36831430288461536
