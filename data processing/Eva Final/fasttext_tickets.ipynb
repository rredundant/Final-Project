# %%
import pandas as pd
import glob
import random
from sklearn.utils import shuffle

# %%
files = glob.glob('/Users/ehamilton/Downloads/Data/*.csv')


li = []

# for filename in files:
#     num_lines = sum(1 for l in open(filename))
#     size = int(num_lines / 6 ) # use these values: 3,4,5,6
#     skip_idx = random.sample(range(1, num_lines), num_lines - size)
#     df = pd.read_csv(filename, skiprows=skip_idx, index_col=None, header=0)
#     li.append(df)

# df = pd.concat(li, axis=0, ignore_index=True)

# # Shuffle the data.
# df = shuffle(df)
# df.head()

for filename in files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)
    
df = pd.concat(li, axis=0, ignore_index=True)

# %%
# df_drop = df[['plan_purchased_nice', 'msg_whole']]
df.fillna(0, inplace=True)
# df_drop.head()

# %%
df.iloc[444].msg_whole
# Out:
# "Your domain was bought 6 days ago.,Would you please cancel the Gsuite subscription I made while we were talking for alixander@slc.agency ? I made an error in ordering it. ,Do you have plans of adding more emails at that domain?,Lol. Thank you. ,Ok, in order to change a domain you need to cancel this and then register a new one. You'll have to pay for the new one, because domains can't be refunded after more than 2 days from purchase.,Confirmation,Sure thing! ,Or do you still have questions?,No. It's my precious. You can't have it! Lol. That blows. Let's say I purchase a new domain name from godaddy, do I have to transfer and host it with WP or am I able to overcome this mistake in a different way?,Hey, I rdered the wrong domain name for this project. I really don't want to purchase a new domain and have to transfer it because of the mistake I made. Would you guys help me out?,Could you confirm you're talking about sellmyreal.estate?,You can't sell a domain, only registrars can sell them.,So if you register a new domain with GoDaddy, you'll pay them to register and us to map it here.,Registrars are companies that have the required authorization to do so.,:(,You would have to pay us anyway to redirect the domain from GoDaddy here. :),The redirect (we call it domain mapping) costs $13 per year.,You're welcome! , ,Yes, sorry! :(,Do you want me to cancel this one?,How would I sell a domain?,So I would transfer hosting from WP to Godaddy and then have them list it for sale?,Just a moment while I check your account.,Actually no, you as an individual can't sell domains,You can have more than one domain pointing at your site as well.,Are you all set now?,Is there anything else I can help you with? ,Hi there! "

# %%
# __domain_primary__ . or 

for_df = []

for index, row in df.iterrows():
    non_zero_tags = []
    plan_purchased_nice = row.plan_purchased_nice
    non_zero_tags.append(plan_purchased_nice)
    non_zero_tags = [x for x in non_zero_tags if x] # if x not zero
    
    if non_zero_tags:
        for_df.append({
            "tags": non_zero_tags,
            "text": row.msg_whole
        })
    else:
        for_df.append({
        "tags": ['notag'],
        "text": row.msg_whole
    })

# %%
from sklearn.utils import shuffle
# __label__sauce __label__cheese How much does potato starch affect a cheese sauce recipe?

out = pd.DataFrame.from_records(for_df)
out['tags'] = out['tags'].map(
    
        lambda x:  " , ".join([ "__label__{}".format(j) for j in x])

)
out = shuffle(out)
out.head()
# Out:
#                     tags                                               text
# 49458   __label__Premium  Hi!  How do I link my site pages to what I hav...
# 60450  __label__Personal  Alright thanks for that. :) ,Hi again, is ther...
# 57693  __label__Personal  I'm not sure what you mean by that. Where are ...
# 65960  __label__Business  They want to use emojis with Elementor—I can't...
# 5814   __label__Personal  Are you able to activate themes from here: htt...

# %%
out['for_fast'] = out.tags + " " + out['text']
out['for_fast'].to_clipboard(index=False)

# %%
out.head()

len(out)
# Out:
# 80000

# %%
# magic commands time
# you are here! /Users/ehamilton/fastTextCLI/fastText-0.2.0
# original file is tickets.txt

head -n 60000 tickets.txt > tickets.train
tail -n 20000 tickets.txt > tickets.valid

./fasttext supervised -input tickets.train -output tickets_model

./fasttext test tickets_model.bin tickets.valid

N	739
P@1	0.286
R@1	0.189
# Out:
#   File "<ipython-input-9-3d38145175fd>", line 5
#     head -n 14988 tickets.txt > tickets.train
#                 ^
# SyntaxError: invalid syntax

# %%
from fastText import load_model

# %%
m = load_model('tickets_model.bin')

# %%
m.predict(df.iloc[555].msg_whole, k=3)
df["Predicted Plan"] = df["msg_whole"].apply(lambda x: m.predict(x)[0][0].split("__")[-1])

df.head()

df.to_csv('predicted_plan_div6.csv')

# %%
df.head()
# Out:
#        users.user_id users.plan_purchase_date happychat_session_date  \
# 2087         2510663               2018-03-28             2018-03-28
# 15632      110585409               2019-04-09             2019-04-26
# 12258       12068033               2019-01-16             2019-01-16
# 14322       33074001               2019-03-04             2019-03-04
# 15874      131402903               2019-04-09             2019-04-10
#
#        happychat_session_id      plan_purchased plan_purchased_nice  \
# 2087                2248462  wp-bundle-business            Business
# 15632              12357700  wp-bundle-business            Business
# 12258               9585425  wp-bundle-business            Business
# 14322              10922410  wp-bundle-business            Business
# 15874              11985244     wp-value-bundle             Premium
#
#                tag_1              tag_2 tag_3 tag_4 tag_5  \
# 2087               0                  0     0     0     0
# 15632  plan_business  billing_autorenew     0     0     0
# 12258              0                  0     0     0     0
# 14322              0                  0     0     0     0
# 15874      happychat                  0     0     0     0
#
#                                                msg_whole Predicted Plan
# 2087   Do you also wish to keep the domain https://dr...       Business
# 15632  You're welcome!,No...Thanks!! Have a good one!...       Business
# 12258  If that's added, an A record is not needed,Tha...       Business
# 14322  So....of course the site I need the business u...       Business
# 15874  Hello, are you still with me?,Can you click on...       Business

# %%
avg [i[1][0] for i in list(df["Predicted Plan"])]

# [i[0][0].split("__")[-1] for i in list(df["Predicted Plan"])]
# Out:
# [0.4587143063545227,
#  0.6672263145446777,
#  0.539897620677948,
#  0.4018714725971222,
#  0.3932005763053894,
#  0.5059995055198669,
#  0.34957849979400635,
#  0.4184507727622986,
#  0.4623998701572418,
#  0.3772382438182831,
#  0.41742566227912903,
#  0.4184507727622986,
#  0.46260327100753784,
#  0.4623998701572418,
#  0.37577763199806213,
#  0.3772382438182831,
#  0.7944203019142151,
#  0.534182071685791,
#  0.534182071685791,
#  0.43845275044441223,
#  0.43845275044441223,
#  0.47459083795547485,
#  0.40141361951828003,
#  0.40141361951828003,
#  0.4857929050922394,
#  0.4857929050922394,
#  0.4033668041229248,
#  0.5077749490737915,
#  0.5423154234886169,
#  0.3863692581653595,
#  0.3863692581653595,
#  0.45065173506736755,
#  0.41780370473861694,
#  0.4774838089942932,
#  0.3894009590148926,
#  0.5507855415344238,
#  0.4942551255226135,
#  0.37779995799064636,
#  0.49353763461112976,
#  0.5925634503364563,
#  0.39890244603157043,
#  0.5507855415344238,
#  0.5507855415344238,
#  0.4942551255226135,
#  0.4942551255226135,
#  0.37779995799064636,
#  0.37779995799064636,
#  0.49353763461112976,
#  0.49353763461112976,
#  0.5925634503364563,
#  0.5925634503364563,
#  0.39890244603157043,
#  0.39890244603157043,
#  0.5942004919052124,
#  0.39868447184562683,
#  0.7645313143730164,
#  0.4096222519874573,
#  0.48511776328086853,
#  0.4877634048461914,
#  0.37531352043151855,
#  0.37543755769729614,
#  0.40756794810295105,
#  0.40796130895614624,
#  0.6136584281921387,
#  0.6259852647781372,
#  0.5105475187301636,
#  0.510680079460144,
#  0.5456648468971252,
#  0.5445881485939026,
#  0.6588514447212219,
#  0.6597188115119934,
#  0.5783721804618835,
#  0.5800933837890625,
#  0.47598978877067566,
#  0.47787824273109436,
#  0.4886937141418457,
#  0.48890554904937744,
#  0.43766990303993225,
#  0.4379715919494629,
#  0.4255243241786957,
#  0.42512258887290955,
#  0.5268969535827637,
#  0.5270256400108337,
#  0.54556804895401,
#  0.5468024015426636,
#  0.43151310086250305,
#  0.43466633558273315,
#  0.41668108105659485,
#  0.4169394373893738,
#  0.4464060962200165,
#  0.4468785524368286,
#  0.4058947265148163,
#  0.40590888261795044,
#  0.41140106320381165,
#  0.42354506254196167,
#  0.41303932666778564,
#  0.3731108605861664,
#  0.4065198302268982,
#  0.38999539613723755,
#  0.4411703050136566,
#  0.396112859249115,
#  0.4042184054851532,
#  0.4351710081100464,
#  0.5987319350242615,
#  0.44598427414894104,
#  0.4175606966018677,
#  0.4689237177371979,
#  0.40290895104408264,
#  0.3672689199447632,
#  0.4096222519874573,
#  0.4877634048461914,
#  0.37543755769729614,
#  0.40796130895614624,
#  0.6259852647781372,
#  0.510680079460144,
#  0.5445881485939026,
#  0.6597188115119934,
#  0.5800933837890625,
#  0.47787824273109436,
#  0.48890554904937744,
#  0.4379715919494629,
#  0.42512258887290955,
#  0.5270256400108337,
#  0.5468024015426636,
#  0.43466633558273315,
#  0.4169394373893738,
#  0.4468785524368286,
#  0.40590888261795044,
#  0.3573352098464966,
#  0.4408028721809387,
#  0.3899044096469879,
#  0.3531733751296997,
#  0.9240143895149231,
#  0.45799678564071655,
#  0.3810608685016632,
#  0.4094657301902771,
#  0.39027631282806396,
#  0.3777240812778473,
#  0.4035229980945587,
#  0.5233195424079895,
#  0.5263621211051941,
#  0.42730051279067993,
#  0.6189395785331726,
#  0.45625415444374084,
#  0.39371350407600403,
#  0.4832880198955536,
#  0.6220232248306274,
#  0.4337800443172455,
#  0.4638877213001251,
#  0.3662056028842926,
#  0.48594892024993896,
#  0.46645957231521606,
#  0.39759939908981323,
#  0.6113672256469727,
#  0.35940319299697876,
#  0.40343227982521057,
#  0.8216093182563782,
#  0.5736059546470642,
#  0.4734593331813812,
#  0.6393243670463562,
#  0.5206804275512695,
#  0.7543568015098572,
#  0.39946627616882324,
#  0.5240338444709778,
#  0.5172005891799927,
#  0.5409696102142334,
#  0.45994117856025696,
#  0.3941996395587921,
#  0.37457332015037537,
#  0.5171524882316589,
#  0.53818279504776,
#  0.4652017056941986,
#  0.3993678092956543,
#  0.3735656142234802,
#  0.5912386775016785,
#  0.3480246663093567,
#  0.39468950033187866,
#  0.4105764627456665,
#  0.528032660484314,
#  0.4420326054096222,
#  0.44446584582328796,
#  0.4263691306114197,
#  0.4220454692840576,
#  0.7440871000289917,
#  0.36844202876091003,
#  ...]

# %%
if 0:
    print('this will not print')

# %%
if 1:
    print('this will print')
# Out:
# this will print

# %%
 # in the dataframe, clean the text a bit
